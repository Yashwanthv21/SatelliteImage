# %%
# !pip install PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# ...
#      |████████████████████████████████| 993kB 2.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# ...

# %%
fileId = drive.CreateFile({'id': '1vEYYmzjFdlyZVPA_FdLHbMXHEc_4HbPm'}) #DRIVE_FILE_ID https://drive.google.com/file/d/1BThl6Kbp-LhvdTX1I3zY4wvuhE1Z0Pji/view
print (fileId['title'])  # folder_data.zip
fileId.GetContentFile('pool.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pydrive/files.py in __getitem__(self, key)
#     133     try:
# --> 134       return dict.__getitem__(self, key)
#     135     except KeyError as e:
#
# KeyError: 'title'
#
# During handling of the above exception, another exception occurred:
#
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pydrive/files.py in FetchMetadata(self, fields, fetch_all)
#     236                                                  fields=fields)\
# --> 237           .execute(http=self.http)
#     238       except errors.HttpError as error:
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# ...

# %%
from keras.models import load_model
import cv2
import numpy as np
from operator import itemgetter
import urllib.request
from keras.preprocessing import image
model = load_model('pool.h5')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-a51f64fce69c> in <module>()
#       5 import urllib.request
#       6 from keras.preprocessing import image
# ----> 7 model = load_model('pool.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     415     model = None
#     416     opened_new_file = not isinstance(filepath, h5py.Group)
# --> 417     f = h5dict(filepath, 'r')
#     418     try:
#     419         model = _deserialize_model(f, custom_objects, compile)
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     184             self._is_file = False
#     185         elif isinstance(path, str):
# --> 186             self.data = h5py.File(path, mode=mode)
#     187             self._is_file = True
# ...

# %%
def downloadMapImage(lat,lng,img_path):
  url = "http://maps.googleapis.com/maps/api/staticmap?center=" + str(lat) + "," + str(lng) + "&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32"
  print(url)
  urllib.request.urlretrieve(url, img_path)

# %%
classes = ["No Swimming Pool","Swimming Pool"]
def decode_predictions(pred):
    pred = dict(zip(classes, pred.tolist()[0]))
    return sorted(pred.items(), key=itemgetter(1))

# %%
from matplotlib.pyplot import imshow 
from matplotlib import pyplot as plt
def check_for_pool(lat,lng):
  """accepts lat and lng of a location and checks if pool is present"""
  # Download the image
  img_path = 'img.png'
  downloadMapImage(lat,lng, img_path)
  # preprocess the image and send for prediction
   
  img = image.load_img(img_path, target_size=(128, 128))
#   imshow(img)
  plt.figure(figsize=(7,7))
  plt.imshow(img)
  plt.grid(True)
  plt.xticks([])
  plt.yticks([])
  img = np.reshape(img,[1,128,128,3])
  return decode_predictions(model.predict(img))

# %%
check_for_pool(30.171399,-95.484196)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=30.171399,-95.484196&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.867820,-95.399274)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.86782,-95.399274&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.703430,-95.409540)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.70343,-95.40954&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.7178131,-95.4045962)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.7178131,-95.4045962&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.703962,-95.410994)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.703962,-95.410994&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.684483, -95.397068)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.684483,-95.397068&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.684502, -95.396497)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.684502,-95.396497&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.686243, -95.395098)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.686243,-95.395098&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.665044, -95.369783)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.665044,-95.369783&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.672996, -95.368267)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.672996,-95.368267&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.03476332128047943),
#  ('Swimming Pool', 0.9652367234230042)]

# %%
check_for_pool(29.888062, -95.508823)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.888062,-95.508823&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.888335, -95.508654)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.888335,-95.508654&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.888333, -95.508459)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.888333,-95.508459&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.683502, -95.33497)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.683502,-95.33497&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(39.684502, -95.396497)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=39.684502,-95.396497&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.884502, -95.386497)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.884502,-95.386497&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('Swimming Pool', 0.0), ('No Swimming Pool', 1.0)]

# %%
check_for_pool(29.886350, -95.600145)
# Out:
# http://maps.googleapis.com/maps/api/staticmap?center=29.88635,-95.600145&size=500x500&zoom=21&sensor=true&maptype=satellite&scale=1&format=png32
# [('No Swimming Pool', 0.0), ('Swimming Pool', 1.0)]

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)

# %%
check_for_pool(29.684502, -95.396497)
